# %% [markdown]
# <a href="https://www.kaggle.com/code/denizherand/haydi-dene?scriptVersionId=194320891" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# denemelisin

# %%
y = 3.2
type(3.2)
# Out:
# float
